# %%
import numpy as np
import matplotlib.pyplot as plt

image = np.load("images/camera2/frame_300.npy")  # Load saved NumPy array
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
image.shape
# Out:
# (1920, 1920, 3)
